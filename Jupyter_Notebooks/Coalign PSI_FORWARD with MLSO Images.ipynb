# %%
# Imports
import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors
import astropy.units as u

# Print the version of sunpy originally used for this notebook
print(f'Sunpy Version: {sunpy.version.version}')
# Out:
# Sunpy Version: 3.1.3

# %%
# Where is the data located?
from astropy.io import fits
fits_dir = '/Users/crura/Desktop/Research/Magnetic_Field/Forward_MLSO_Projection.fits'
data = fits.getdata(fits_dir)
head = fits.getheader(fits_dir)

# head['hgln_obs'] = head['CRLN_OBS']
#head['hglt_obs'] = head['CRLT_OBS']

# Read the image as a Map
psimap = sunpy.map.Map(data, head) 
#psimap.plot_settings['norm'] = plt.Normalize(mlsomap.min(), mlsomap.max())

fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

# add KCor as detector to fits file header
from astropy.io import fits
data = fits.getdata(fits_dir_mlso)
head = fits.getheader(fits_dir_mlso)
#mlsomap.fits_header.insert('Detector', 'kcor')
head['detector'] = ('KCor')
mlsomap = sunpy.map.Map(data, head) 


# head['hgln_obs'] = head['CRLN_OBS']
# head['hglt_obs'] = head['CRLT_OBS']


#head['DATE-OBS'] = '2017-08-30T02:23:16.968Z'
# hdunew = fits.PrimaryHDU(data=data,header=head)
# hdunew.writeto(fits_dir_mlso,overwrite=True)

# Read the image as a Map
#mlsomap = sunpy.map.Map(fits_dir_mlso)

mlsomap.plot_settings['cmap'] = "Greys_r"
#mlsomap.plot_settings['norm'] = plt.Normalize(1e-10, 1e-7)



fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psimap)
psimap.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)

# %%
head
# Out:
# SIMPLE  =                    T / Written by IDL:  Mon Jan 17 17:24:04 2022
# BITPIX  =                  -32 / bits per pixel
# NAXIS   =                    2 / number of dimensions; FITS image
# NAXIS1  =                 1024 /Number of positions along axis 1
# NAXIS2  =                 1024 /Number of positions along axis 2
# EXTEND  =                    F / no FITS extensions
# DATE-OBS= '2017-08-29T20:08:01' / UTC observation start
# DATE-END= '2017-08-29T20:08:47' / UTC observation end
# TIMESYS = 'UTC     '           / date/time system: Coordinated Universal Time
# DATE_HST= '2017-08-29T10:08:01' / MLSO observation date [HST]
# LOCATION= 'MLSO    '           / Mauna Loa Solar Observatory, Hawaii
# ORIGIN  = 'NCAR/HAO'           / Nat.Ctr.Atmos.Res. High Altitude Observatory
# TELESCOP= 'COSMO K-Coronagraph' / COSMO: COronal Solar Magnetism Observatory
# INSTRUME= 'COSMO K-Coronagraph' /
# WAVELNTH=                  735 / [nm] center wavelength of bandpass filter
# ...

# %%
mlsomap
# Out:
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1024.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        ...,
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09]],
#       dtype=float32)

# %%
# Imports
import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors

# Print the version of sunpy originally used for this notebook
print(f'Sunpy Version: {sunpy.version.version}')
# Where is the data located?
fits_dir = '/Users/crura/Desktop/Research/Magnetic_Field/Forward_MLSO_Projection.fits'

from astropy.io import fits
data = fits.getdata(fits_dir)
head = fits.getheader(fits_dir)

# head['hgln_obs'] = head['CRLN_OBS']
#head['hglt_obs'] = head['CRLT_OBS']

# Read the image as a Map
psimap = sunpy.map.Map(data, head) 
psimap.plot_settings['norm'] = plt.Normalize(mlsomap.min(), mlsomap.max())

# Print the map information (see WCS info/plate scale has been loaded)
psimap
# Out:
# Sunpy Version: 3.1.3
# ...
# SunPy Map
# ---------
# Observatory:		 PSI-MAS Forward Model
# Instrument:		 not specified
# Detector:		 not_specified
# Measurement:		 -1.0
# Wavelength:		 -1.0
# Observation Date:	 2017-08-30 02:23:16
# Exposure Time:		 1.0 s
# Dimension:		 [256. 256.] pix
# Coordinate System:	 helioprojective
# Scale:			 [45.5348056 45.5348056] arcsec / pix
# Reference Pixel:	 [127. 127.] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[148409.62193811, 149357.60931816, 150346.29294781, ...,
#         118277.66662472, 117537.90273486, 116792.49860723],
#        [150406.05277255, 151348.68888061, 152327.63489609, ...,
#         119877.84545582, 119100.93788483, 118316.53518773],
#        [152468.20404842, 153420.76060381, 154392.33092896, ...,
#         121491.1201365 , 120675.68607572, 119854.3930238 ],
#        ...,
#        [138744.76843528, 139111.59717353, 139510.53719369, ...,
#         106921.08707612, 106282.74647892, 105646.74233828],
# ...

# %%
psimap.plot_settings['norm'] = plt.Normalize(mlsomap.min(), mlsomap.max())
out_psi = psimap.reproject_to(mlsomap.wcs)

# %%
out_psi
# Out:
# ...
# SunPy Map
# ---------
# Observatory:
# Instrument:
# Detector:
# Measurement:		 Unknown
# Wavelength:		 Unknown
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 Unknown
# Dimension:		 [1024. 1024.] pix
# Coordinate System:	 helioprojective
# Scale:			 [0.0015675 0.0015675] deg / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] deg
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
mlsomap.max()
# Out:
# 1.1402144e-06

# %%
psimap.data
# Out:
# ...
# SunPy Map
# ---------
# Observatory:		 PSI-MAS Forward Model
# Instrument:		 not specified
# Detector:		 not_specified
# Measurement:		 -1.0
# Wavelength:		 -1.0
# Observation Date:	 2017-08-30 02:23:16
# Exposure Time:		 1.0 s
# Dimension:		 [256. 256.] pix
# Coordinate System:	 helioprojective
# Scale:			 [45.5348056 45.5348056] arcsec / pix
# Reference Pixel:	 [127. 127.] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[148409.62193811, 149357.60931816, 150346.29294781, ...,
#         118277.66662472, 117537.90273486, 116792.49860723],
#        [150406.05277255, 151348.68888061, 152327.63489609, ...,
#         119877.84545582, 119100.93788483, 118316.53518773],
#        [152468.20404842, 153420.76060381, 154392.33092896, ...,
#         121491.1201365 , 120675.68607572, 119854.3930238 ],
#        ...,
#        [138744.76843528, 139111.59717353, 139510.53719369, ...,
#         106921.08707612, 106282.74647892, 105646.74233828],
# ...

# %%
mlsomap.carrington_latitude
# Out:
# <Latitude 0. deg>

# %%
mlsomap.fits_header.insert('detector', 'kcor')
mlsomap
# Out:
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1024.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        ...,
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09],
#        [-7.e-09, -7.e-09, -7.e-09, ..., -7.e-09, -7.e-09, -7.e-09]],
#       dtype=float32)

# %%
mlsomap.coordinate_frame
# Out:
# <Helioprojective Frame (obstime=2017-08-29T20:08:01.000, rsun=695971.78757675 km, observer=<HeliographicStonyhurst Coordinate (obstime=2017-08-29T20:08:01.000, rsun=695971.78757675 km): (lon, lat, radius) in (deg, deg, m)
#     (0., 0., 1.51054868e+11)>)>

# %%
mlsomap.fits_header
# Out:
# WARNING: SunpyMetadataWarning: The meta key comment is not valid ascii, dropping from the FITS header [sunpy.io.fits]
# WARNING: SunpyMetadataWarning: The meta key history is not valid ascii, dropping from the FITS header [sunpy.io.fits]
# SIMPLE  =                    T
# BITPIX  =                  -32
# NAXIS   =                    2
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# EXTEND  =                    F
# DATE-OBS= '2017-08-29T20:08:01'
# DATE-END= '2017-08-29T20:08:47'
# TIMESYS = 'UTC     '
# DATE_HST= '2017-08-29T10:08:01'
# LOCATION= 'MLSO    '
# ORIGIN  = 'NCAR/HAO'
# TELESCOP= 'COSMO K-Coronagraph'
# INSTRUME= 'COSMO K-Coronagraph'
# WAVELNTH=                  735
# WAVEFWHM=                   30
# OBJECT  = 'Solar K-Corona'
# DATATYPE= 'science '
# OBSERVER= 'Stueben '
# SKYTRANS=                0.979
# BIASCORR=                    0
# SKYPOLRM= 'subtraction'
# AVGTIME0= '20:08:01 20:08:16 20:08:31 20:08:47'
# AVGTIME1= ''
# DARKSHUT= 'out     '
# ...

# %%
psimap.coordinate_frame
# Out:
# <Helioprojective Frame (obstime=2017-08-30T02:23:16.968, rsun=696000.0 km, observer=<HeliographicStonyhurst Coordinate (obstime=2017-08-30T02:23:16.968, rsun=696000.0 km): (lon, lat, radius) in (deg, deg, m)
#     (3.48775534, 7.153, 1.49597871e+11)>)>

# %%
psimap.fits_header
# Out:
# SIMPLE  =                    T / Written by IDL:  Wed Feb 23 11:29:20 2022
# BITPIX  =                  -64 / Real*8 (double precision)
# NAXIS   =                    2
# NAXIS1  =                  256
# NAXIS2  =                  256
# DATE_OBS= '2017-08-30T02:23:16.968Z'
# T_REC   = '2017-08-30T02:23:16.968Z'
# T_OBS   = '2017-08-30T02:23:16.968Z'
# OBSRVTRY= 'PSI-MAS Forward Model'
# INSTRUME= 'not_specified'
# TELESCOP= 'not_specified'
# DETECTOR= 'not_specified'
# IMG_TYPE= 'model   '
# EXPTIME =                  1.0
# WAVELNTH=                 -1.0
# WAVEUNIT= ''
# BUNIT   = 'not_specified'
# CTYPE1  = 'HPLN-TAN'
# CUNIT1  = 'arcsec  '
# CRVAL1  =                  0.0
# CDELT1  =        45.5348056012
# CRPIX1  =                  128
# CTYPE2  = 'HPLT-TAN'
# CUNIT2  = 'arcsec  '
# CRVAL2  =                  0.0
# CDELT2  =        45.5348056012
# CRPIX2  =                  128
# CROTA2  =                  0.0
# R_SUN   =        21.0747457467
# DSUN_REF=       149597870691.0
# ...

# %%
all_hpc = sunpy.map.all_coordinates_from_map(mlsomap)
all_hpc2 = sunpy.map.all_coordinates_from_map(psimap)

# %%
all_hpc
# Out:
# <SkyCoord (Helioprojective: obstime=2017-08-29T20:08:01.000, rsun=695971.78757675 km, observer=<HeliographicStonyhurst Coordinate (obstime=2017-08-29T20:08:01.000, rsun=695971.78757675 km): (lon, lat, radius) in (deg, deg, m)
#     (0., 0., 1.51054868e+11)>): (Tx, Ty) in arcsec
#     [[(-2886.20611578, -2885.92360307), (-2880.56421843, -2885.92470647),
#       (-2874.92231677, -2885.92580771), ...,
#       ( 2874.92231677, -2885.92580771), ( 2880.56421843, -2885.92470647),
#       ( 2886.20611578, -2885.92360307)],
#      [(-2886.20611578, -2880.28225782), (-2880.56421843, -2880.28335907),
#       (-2874.92231677, -2880.28445816), ...,
#       ( 2874.92231677, -2880.28445816), ( 2880.56421843, -2880.28335907),
#       ( 2886.20611578, -2880.28225782)],
#      [(-2886.20611578, -2874.64090827), (-2880.56421843, -2874.64200736),
#       (-2874.92231677, -2874.6431043 ), ...,
#       ( 2874.92231677, -2874.6431043 ), ( 2880.56421843, -2874.64200736),
# ...

# %%
all_hpc2
# Out:
# <SkyCoord (Helioprojective: obstime=2017-08-30T02:23:16.968, rsun=696000.0 km, observer=<HeliographicStonyhurst Coordinate (obstime=2017-08-30T02:23:16.968, rsun=696000.0 km): (lon, lat, radius) in (deg, deg, m)
#     (3.48775534, 7.153, 1.49597871e+11)>): (Tx, Ty) in arcsec
#     [[(-5781.40582506, -5779.13614669), (-5735.90650284, -5779.1717283 ),
#       (-5690.40662226, -5779.20702929), ...,
#       ( 5735.90650284, -5779.1717283 ), ( 5781.40582506, -5779.13614669),
#       ( 5826.90458452, -5779.10028447)],
#      [(-5781.40582506, -5733.65466822), (-5735.90650284, -5733.68997009),
#       (-5690.40662226, -5733.72499355), ...,
#       ( 5735.90650284, -5733.68997009), ( 5781.40582506, -5733.65466822),
#       ( 5826.90458452, -5733.61908793)],
#      [(-5781.40582506, -5688.17263205), (-5735.90650284, -5688.20765418),
#       (-5690.40662226, -5688.24240009), ...,
#       ( 5735.90650284, -5688.20765418), ( 5781.40582506, -5688.17263205),
# ...

# %%
CRLT_OBS=                7.153                                                  
CRLN_OBS=              183.443

# %%
head['CRLN_OBS']
# Out:
# 183.443

# %%
head[]
# Out:
# SIMPLE  =                    T / Written by IDL:  Wed Feb 23 11:29:20 2022
# BITPIX  =                  -64 / Real*8 (double precision)
# NAXIS   =                    2 /
# NAXIS1  =                  256 /
# NAXIS2  =                  256 /
# DATE_OBS= '2017-08-30T02:23:16.968Z' /
# T_REC   = '2017-08-30T02:23:16.968Z' /
# T_OBS   = '2017-08-30T02:23:16.968Z' /
# OBSRVTRY= 'PSI-MAS Forward Model' /
# INSTRUME= 'not_specified'      /
# TELESCOP= 'not_specified'      /
# DETECTOR= 'not_specified'      /
# IMG_TYPE= 'model   '           /
# EXPTIME =        1.00000000000 /
# WAVELNTH=       -1.00000000000 /
# WAVEUNIT= '        '           /
# BUNIT   = 'not_specified'      /
# CTYPE1  = 'HPLN-TAN'           /
# CUNIT1  = 'arcsec  '           /
# CRVAL1  =        0.00000000000 /
# CDELT1  =        45.5348056012 /
# CRPIX1  =                  128 /
# CTYPE2  = 'HPLT-TAN'           /
# CUNIT2  = 'arcsec  '           /
# CRVAL2  =        0.00000000000 /
# CDELT2  =        45.5348056012 /
# ...

# %%
fig = plt.figure(figsize=(12, 5))

#psimap.plot_settings['norm'] = plt.Normalize(mlsomap.min(), mlsomap.max()) # colors.LogNorm(100, aiamap.max()) 
#psimap.plot_settings['norm'] = plt.Normalize(mlsomap.min(), mlsomap.max()) # colors.LogNorm(100, aiamap.max()) 

psimap.plot_settings['norm'] = plt.Normalize(mlsomap.min(), mlsomap.max())
psimap.plot_settings['cmap'] = plt.get_cmap('Greys_r')
psimap.plot_settings['cmap'].set_bad('k')

ax1 = fig.add_subplot(1, 2, 1, projection=mlsomap)
mlsomap.plot(axes=ax1)#, clip_interval=(1, 99.9)*u.percent)
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
psimap.plot(axes=ax2,norm = matplotlib.colors.LogNorm(mlsomap.min(), mlsomap.min()), autoalign=True, title='MLSO Image in PSI Reference Frame')
ax2.axis(ax1.axis())
# Out:
# /var/folders/26/b7qh5qwx09j4pmkbr4j6r8jr0000gp/T/ipykernel_50859/1343769692.py:8: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("Greys_r").copy()
#   psimap.plot_settings['cmap'].set_bad('k')
# (-0.5, 1023.5, -0.5, 1023.5)

# %%
from astropy.coordinates import get_sun_L0
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/26/b7qh5qwx09j4pmkbr4j6r8jr0000gp/T/ipykernel_50859/3271887885.py in <module>
# ----> 1 from astropy.coordinates import get_sun_L0
#
# ImportError: cannot import name 'get_sun_L0' from 'astropy.coordinates' (/Users/crura/.conda/envs/test_env/lib/python3.9/site-packages/astropy/coordinates/__init__.py)

# %%
psi_data = psimap.data.copy()
plt.imshow(psi_data,norm=matplotlib.colors.LogNorm(),origin='lower')

# %%
matplotlib.colors.Normalize(mlsomap.min(), mlsomap.max())

# %%
mlsomap.bottom_left_coord
# Out:
# <SkyCoord (Helioprojective: obstime=2017-08-29T20:08:01.000, rsun=695971.78757675 km, observer=<HeliographicStonyhurst Coordinate (obstime=2017-08-29T20:08:01.000, rsun=695971.78757675 km): (lon, lat, radius) in (deg, deg, m)
#     (0., 0., 1.51054868e+11)>): (Tx, Ty) in arcsec
#     (-2886.20611578, -2885.92360307)>

# %%
psi_data.shape,psimap.data.shape
# Out:
# ((1024, 1024), (256, 256))

# %%
import pandas as pd
psi_mlso_proj =pd.read_csv('/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_MLSO_Coalignment.csv', sep=',',header=None)


psi_mlso_proj_values = psi_mlso_proj.values

# %%
plt.imshow(psi_mlso_proj_values,norm=matplotlib.colors.LogNorm(),origin='lower',cmap='Greys_r')

# %%
out_psi.data = psi_mlso_proj_values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/26/b7qh5qwx09j4pmkbr4j6r8jr0000gp/T/ipykernel_50859/4000385814.py in <module>
# ----> 1 out_psi.data = psi_mlso_proj_values
#
# AttributeError: can't set attribute

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

# add KCor as detector to fits file header
from astropy.io import fits
data = psi_mlso_proj_values
head = fits.getheader(fits_dir_mlso)
#mlsomap.fits_header.insert('Detector', 'kcor')
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')

psi_coalign_map = sunpy.map.Map(data, head) 
psi_coalign_map
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1024.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[ 993858.9665197 ,  995535.54840608,  997212.18190182, ...,
#          777004.20454732,  775105.80968996,  773207.6485675 ],
#        [ 998331.70510759, 1000085.03901928, 1001838.42690296, ...,
#          779676.93154289,  777764.31014547,  775851.92423455],
#        [1002804.58137751, 1004634.66967714, 1006464.81431144, ...,
# ...

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psi_coalign_map)
ax1.set_title('PSI-Forward Model')
psi_coalign_map.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)
plt.show()

# %%
psi_coalign_map.fits_header
# Out:
# WARNING: SunpyMetadataWarning: The meta key comment is not valid ascii, dropping from the FITS header [sunpy.io.fits]
# WARNING: SunpyMetadataWarning: The meta key observatory is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io.fits]
# WARNING: SunpyMetadataWarning: The meta key history is not valid ascii, dropping from the FITS header [sunpy.io.fits]
# SIMPLE  =                    T
# BITPIX  =                  -32
# NAXIS   =                    2
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# EXTEND  =                    F
# DATE-OBS= '2017-08-29T20:08:01'
# DATE-END= '2017-08-29T20:08:47'
# TIMESYS = 'UTC     '
# DATE_HST= '2017-08-29T10:08:01'
# LOCATION= 'MLSO    '
# ORIGIN  = 'NCAR/HAO'
# TELESCOP= 'COSMO K-Coronagraph'
# INSTRUME= 'COSMO K-Coronagraph'
# WAVELNTH=                  735
# WAVEFWHM=                   30
# OBJECT  = 'Solar K-Corona'
# DATATYPE= 'science '
# OBSERVER= 'Stueben '
# ...

# %% [markdown]
# # Forward PB Coaligned Image

# %%
import pandas as pd
psi_mlso_proj_pb =pd.read_csv('/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_PB_MLSO_Coalignment.csv', sep=',',header=None)


psi_mlso_proj_pb_values = psi_mlso_proj_pb.values

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

# add KCor as detector to fits file header
from astropy.io import fits
data = psi_mlso_proj_pb_values
head = fits.getheader(fits_dir_mlso)
#mlsomap.fits_header.insert('Detector', 'kcor')
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')

psi_coalign_map_pb = sunpy.map.Map(data, head) 
psi_coalign_map_pb
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1024.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[ 993858.9665197 ,  995535.54840608,  997212.18190182, ...,
#          777004.20454732,  775105.80968996,  773207.6485675 ],
#        [ 998331.70510759, 1000085.03901928, 1001838.42690296, ...,
#          779676.93154289,  777764.31014547,  775851.92423455],
#        [1002804.58137751, 1004634.66967714, 1006464.81431144, ...,
# ...

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psi_coalign_map_pb)
ax1.set_title('PSI-Forward Model')
psi_coalign_map_pb.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)
ax2.title.set_text('MLSO K-COR Observation 2017-08-29')
ax1.title.set_text('PSI/FORWARD Synthetic Polarized Brightness Eclipse Model')
plt.savefig('/Users/crura/Desktop/Research/Presentations/URD_22_Pictures/Model_Comparison.png')
plt.show()

# %% [markdown]
# # Central Coaligned B Field Rotated to MLSO perspective

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

import pandas as pd
fits_dir_bx_central_coaligned = '/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_Bx_Central_MLSO_Coalignment.csv'
psi_bx_central_coaligned =pd.read_csv(fits_dir_bx_central_coaligned)
psi_bx_central_coaligned_values = psi_bx_central_coaligned.values

import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors
from astropy.io import fits

data = psi_bx_central_coaligned_values
head = fits.getheader(fits_dir_mlso)
# add KCor as detector to fits file header
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')


# Read the image as a Map
psimap_bx_central_coaligned = sunpy.map.Map(data, head)

# Print the map information (see WCS info/plate scale has been loaded)
psimap_bx_central_coaligned
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1023.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[-0.00231077, -0.00231439, -0.00231801, ..., -0.00248787,
#         -0.00247921, -0.00247055],
#        [-0.00231613, -0.00231973, -0.00232333, ..., -0.00249128,
#         -0.0024826 , -0.00247391],
#        [-0.00232148, -0.00232507, -0.00232865, ..., -0.00249469,
#         -0.00248598, -0.00247728],
#        ...,
#        [ 0.00284973,  0.00285904,  0.00286836, ...,  0.00144312,
# ...

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psimap_bx_central_coaligned)
ax1.set_title('PSI-Forward Model')
psimap_bx_central_coaligned.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)
plt.show()

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

import pandas as pd
fits_dir_by_central_coaligned = '/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_By_Central_MLSO_Coalignment.csv'
psi_by_central_coaligned =pd.read_csv(fits_dir_by_central_coaligned)
psi_by_central_coaligned_values = psi_by_central_coaligned.values

import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors
from astropy.io import fits

data = psi_by_central_coaligned_values
head = fits.getheader(fits_dir_mlso)
# add KCor as detector to fits file header
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')


# Read the image as a Map
psimap_by_central_coaligned = sunpy.map.Map(data, head)

# Print the map information (see WCS info/plate scale has been loaded)
psimap_by_central_coaligned
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1023.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[ 0.03981176,  0.03987296,  0.03993416, ..., -0.04025041,
#         -0.0401779 , -0.04010539],
#        [ 0.03993055,  0.03999224,  0.04005394, ..., -0.04036031,
#         -0.04028738, -0.04021446],
#        [ 0.04004934,  0.04011153,  0.04017373, ..., -0.04047021,
#         -0.04039686, -0.04032352],
#        ...,
#        [-0.03749877, -0.03757185, -0.03764493, ...,  0.03893097,
# ...

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psimap_by_central_coaligned)
ax1.set_title('PSI-Forward Model')
psimap_by_central_coaligned.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)
plt.show()

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

import pandas as pd
fits_dir_bz_central_coaligned = '/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_Bz_Central_MLSO_Coalignment.csv'
psi_bz_central_coaligned =pd.read_csv(fits_dir_bz_central_coaligned)
psi_bz_central_coaligned_values = psi_bz_central_coaligned.values

import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors
from astropy.io import fits

data = psi_bz_central_coaligned_values
head = fits.getheader(fits_dir_mlso)
# add KCor as detector to fits file header
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')


# Read the image as a Map
psimap_bz_central_coaligned = sunpy.map.Map(data, head)

# Print the map information (see WCS info/plate scale has been loaded)
psimap_bz_central_coaligned
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1023.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[0.03539187, 0.03550456, 0.03561726, ..., 0.0315975 , 0.03148839,
#         0.03137929],
#        [0.03541906, 0.03553208, 0.0356451 , ..., 0.03160579, 0.03149648,
#         0.03138719],
#        [0.03544626, 0.0355596 , 0.03567294, ..., 0.03161408, 0.03150458,
#         0.03139509],
#        ...,
#        [0.03107747, 0.03117394, 0.03127042, ..., 0.02792462, 0.02782757,
# ...

# %% [markdown]
# # Coaligned LOS B Field Rotated to MLSO perspective

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

import pandas as pd
fits_dir_bx_los_coaligned = '/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_Bx_LOS_MLSO_Coalignment.csv'
psi_bx_los_coaligned =pd.read_csv(fits_dir_bx_los_coaligned)
psi_bx_los_coaligned_values = psi_bx_los_coaligned.values

import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors
from astropy.io import fits

data = psi_bx_los_coaligned_values
head = fits.getheader(fits_dir_mlso)
# add KCor as detector to fits file header
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')


# Read the image as a Map
psimap_bx_los_coaligned = sunpy.map.Map(data, head)

# Print the map information (see WCS info/plate scale has been loaded)
psimap_bx_los_coaligned
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1023.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[-0.08894788, -0.08920367, -0.08945947, ..., -0.09511973,
#         -0.09489013, -0.09466055],
#        [-0.08901616, -0.08926678, -0.08951741, ..., -0.0952824 ,
#         -0.09505186, -0.09482136],
#        [-0.08908445, -0.0893299 , -0.08957536, ..., -0.09544507,
#         -0.0952136 , -0.09498216],
#        ...,
#        [ 0.10802726,  0.1082004 ,  0.10837355, ...,  0.07299289,
# ...

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psimap_bx_los_coaligned)
ax1.set_title('PSI-Forward Model')
psimap_bx_los_coaligned.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)
plt.show()

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

import pandas as pd
fits_dir_by_los_coaligned = '/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_By_LOS_MLSO_Coalignment.csv'
psi_by_los_coaligned =pd.read_csv(fits_dir_by_los_coaligned)
psi_by_los_coaligned_values = psi_by_los_coaligned.values

import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors
from astropy.io import fits

data = psi_by_los_coaligned_values
head = fits.getheader(fits_dir_mlso)
# add KCor as detector to fits file header
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')


# Read the image as a Map
psimap_by_los_coaligned = sunpy.map.Map(data, head)

# Print the map information (see WCS info/plate scale has been loaded)
psimap_by_los_coaligned
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1023.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[ 2.1673455 ,  2.17048656,  2.17362772, ..., -2.22441719,
#         -2.22079523, -2.21717373],
#        [ 2.17347768,  2.17663843,  2.17979927, ..., -2.23045792,
#         -2.22681225, -2.22316704],
#        [ 2.17960986,  2.18279029,  2.18597082, ..., -2.23649865,
#         -2.23282927, -2.22916034],
#        ...,
#        [-2.16051331, -2.16433365, -2.16815411, ...,  2.2527099 ,
# ...

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psimap_by_los_coaligned)
ax1.set_title('PSI-Forward Model')
psimap_by_los_coaligned.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)
plt.show()

# %%
fits_dir_mlso = '/Users/crura/Desktop/Research/Magnetic_Field/Coalign/20170829_200801_kcor_l2_avg.fts'

import pandas as pd
fits_dir_bz_los_coaligned = '/Users/crura/Desktop/Research/Magnetic_Field/FORWARD_MLSO_Rotated_Data/PSI_Bz_LOS_MLSO_Coalignment.csv'
psi_bz_los_coaligned =pd.read_csv(fits_dir_bz_los_coaligned)
psi_bz_los_coaligned_values = psi_bz_los_coaligned.values

import sunpy.version
import sunpy.map
import matplotlib.pyplot as plt
import matplotlib.colors
from astropy.io import fits

data = psi_bz_los_coaligned_values
head = fits.getheader(fits_dir_mlso)
# add KCor as detector to fits file header
head['Observatory'] = ('PSI-MAS')
head['detector'] = ('KCor')


# Read the image as a Map
psimap_bz_los_coaligned = sunpy.map.Map(data, head)

# Print the map information (see WCS info/plate scale has been loaded)
psimap_bz_los_coaligned
# Out:
# WARNING: VerifyWarning: Keyword name 'Observatory' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ...
# SunPy Map
# ---------
# Observatory:		 MLSO
# Instrument:		 COSMO K-Coronagraph
# Detector:		 KCor
# Measurement:		 735.0 nm
# Wavelength:		 735.0 nm
# Observation Date:	 2017-08-29 20:08:01
# Exposure Time:		 0.0025 s
# Dimension:		 [1024. 1023.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.643 5.643] arcsec / pix
# Reference Pixel:	 [511.5 511.5] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[1.95828019, 1.96441522, 1.97055044, ..., 1.77067362, 1.76489172,
#         1.75911054],
#        [1.95931663, 1.96546194, 1.97160744, ..., 1.77112609, 1.76533355,
#         1.75954173],
#        [1.96035308, 1.96650866, 1.97266444, ..., 1.77157857, 1.76577538,
#         1.75997292],
#        ...,
#        [1.86779696, 1.87366898, 1.87954118, ..., 1.68077522, 1.67526454,
# ...

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 2, 1, projection=psimap_bz_los_coaligned)
ax1.set_title('PSI-Forward Model')
psimap_bz_los_coaligned.plot(axes=ax1,norm=matplotlib.colors.LogNorm())
ax2 = fig.add_subplot(1, 2, 2, projection=mlsomap)
mlsomap.plot(axes=ax2)
plt.show()
