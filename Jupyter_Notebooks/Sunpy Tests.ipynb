# %%
import sunpy

# %%
from sunpy.sun import constants as con

# %%
con.au
# Out:
# <<class 'astropy.constants.iau2015.IAU2015'> name='Astronomical Unit' value=149597870700.0 uncertainty=0.0 unit='m' reference='IAU 2012 Resolution B2'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci
ylist = []
x = np.linspace(5000,30000,30000)
for i in range(0,x.shape[0]):
    y = 8.23 * np.exp(2.50*10**4 /x[i]) / (1 + 4.4 * 10**-3 * 1.16*10**3 /x[i]**(1/2))
    ylist.append(y)
plt.plot(x,ylist)
plt.show()

# %%
x[0],x[-1],ylist[5000]
# Out:
# (200.0, 30000.0, 970.4323817859553)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci

# create list to store y values (in this case ratio of emission coefficients)
ylist = []

# create x array (in this case Temperature) from 7000 to 30000
x = np.linspace(7000,30000,1000000)

# for each x, populate y list using equation 5.7 in textbook
for i in range(0,x.shape[0]):
    y = 5.44 * np.exp(2.28*10**4 /x[i]) / (1 + 3.5 * 10**-4 * 1.16*10**3 /x[i]**(1/2))
    ylist.append(y)
    
# find where y is closest to 20 in y list
condition = np.where(20== np.round(ylist,3))[0][0]

# graph and show solution
plt.plot(x,ylist)
plt.axvline(x=x[condition],linestyle='--',color='r',label='T = {} K'.format(np.round(x[condition],3)))
plt.axhline(y=20,linestyle='--',color='g',label='ratio of emission = {}'.format(np.round(ylist[condition],3)))
plt.xlabel('T (K)')
plt.ylabel('ratio of emission coefficients')
plt.legend()
plt.show()

# %%
ylist[14500]
# Out:
# 20.59977837369052

# %%
ylist[np.where(20== np.round(ylist))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-43776ec376f1> in <module>
# ----> 1 ylist[np.where(20== np.round(ylist))]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
np.where(20== np.round(ylist,3))[0][0]
# Out:
# 12915

# %%
np.shape(np.where(20== np.round(ylist,3)))
# Out:
# (1, 1)

# %%
ylist[14965],ylist[np.where(20== np.round(ylist,3))[0][0]]
# Out:
# (19.99962088486845, 19.99962088486845)

# %%
x[np.where(20== np.round(ylist,3))[0][0]], ylist[np.where(20== np.round(ylist,3))[0][0]]
# Out:
# (17470.715690523015, 20.000416739912446)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci

# create list to store y values (in this case ratio of emission coefficients)
ylist = []

# create x array (in this case Temperature) from 7000 to 30000
x = np.linspace(7000,30000,1000000)

# for each x, populate y list using equation 5.7 in textbook
for i in range(0,x.shape[0]):
    y = 8.23 * np.exp(2.50*10**4 /x[i]) / (1 + 4.4 * 10**-3 * 1.16*10**3 /x[i]**(1/2))
    ylist.append(y)
    
# find where y is closest to 20 in y list
condition = np.where(61.176== np.round(ylist,3))[0][0]

# graph and show solution
plt.plot(x,ylist)
plt.axvline(x=x[condition],linestyle='--',color='r',label='T = {} K'.format(np.round(x[condition],3)))
plt.axhline(y=61.176,linestyle='--',color='g',label='ratio of emission = {}'.format(np.round(ylist[condition],3)))
plt.xlabel('T (K)')
plt.ylabel('ratio of emission coefficients')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci

# create list to store y values (in this case ratio of emission coefficients)
ylist = []

# create x array (in this case Temperature) from 7000 to 30000
x = np.linspace(8000,40000,1000000)

# for each x, populate y list using equation 5.7 in textbook
for i in range(0,x.shape[0]):
    y = 13.7 * np.exp(4.30*10**4 /x[i]) / (1 + 3.8 * 10**-5 * 1.16*10**3 /x[i]**(1/2))
    ylist.append(y)
    
# find where y is closest to 20 in y list
condition = np.where(215.2== np.round(ylist,1))[0][0]

# graph and show solution
plt.plot(x,ylist)
plt.axvline(x=x[condition],linestyle='--',color='r',label='T = {} K'.format(np.round(x[condition],3)))
plt.axhline(y=215.217,linestyle='--',color='g',label='ratio of emission = {}'.format(np.round(ylist[condition],3)))
plt.xlabel('T (K)')
plt.ylabel('ratio of emission coefficients')
plt.legend()
plt.show()

# %%
ylist[110]
# Out:
# 1976.1549815544133
